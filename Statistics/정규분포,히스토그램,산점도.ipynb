# %%
#정규분포
import scipy.stats as stats
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(stats.norm.ppf(.01), stats.norm.ppf(.99), 100)
y = stats.norm(0, 1).pdf(x)        

plt.figure(figsize=(10, 6))          # 플롯 사이즈 지정
plt.plot(x, y, color="red")         # 선을 빨강색으로 지정하여 plot 작성          
plt.xlabel("x")                      # x축 레이블 지정
plt.ylabel("y")                      # y축 레이블 지정
plt.grid()                           # 플롯에 격자 보이기
plt.title("Normal Distribution with scipy.stats")     # 타이틀 표시
plt.legend(["N(0, 1)"])              # 범례 표시
plt.show()

# %%
#히스토그램

y = stats.norm().rvs(size=1000)

# 정규분포 형태를 점선으로 표현
plt.plot(x, stats.norm.pdf(x), 'b--', lw=2, label='normal distribution')
# 발생한 난수의 히스토그램 작성
plt.hist(y, density=True, histtype='stepfilled', bins=20, alpha=.2, label='random freqency')
plt.title('Random Size = ' + str(1000))
plt.xlabel('x')
plt.ylabel('p(x)')
plt.legend()
plt.grid()

# %%
#산점도

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

iris = sns.load_dataset('iris')

sns.pairplot(iris, diag_kind='hist')

plt.show()

# %%
sns.pairplot(iris, 
             diag_kind='kde',
             hue="species", 
             palette='bright') # pastel, bright, deep, muted, colorblind, dark

plt.show()

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(iris, 
               alpha=0.5, 
               figsize=(8, 8), 
               diagonal='kde')
plt.show()
