# %%
! pip install git+https://github.com/ildoonet/pytorch-randaugment
# Out:
# Collecting git+https://github.com/ildoonet/pytorch-randaugment
#   Cloning https://github.com/ildoonet/pytorch-randaugment to c:\users\knigh\appdata\local\temp\pip-req-build-sbswmwc1
#   Running command git clone -q https://github.com/ildoonet/pytorch-randaugment 'C:\Users\knigh\AppData\Local\Temp\pip-req-build-sbswmwc1'

# %%
from RandAugment import RandAugment
import matplotlib.pyplot as plt 
from PIL import *

# %%
img_augment = RandAugment(2,15) #0-30


img_origal = Image.open(r'Dugong.jpg')
img_final = img_augment(img_origal)
plt.imshow(img_final)
plt.show()

# %%
img_augment = RandAugment(4,10)
img_origal = Image.open(r'Dugong.jpg')
img_final = img_augment(img_origal)
plt.imshow(img_final)
plt.show()

# %%
img_augment = RandAugment(4,15)
img_origal = Image.open(r'Dugong.jpg')
img_final = img_augment(img_origal)
plt.imshow(img_final)
plt.show()
