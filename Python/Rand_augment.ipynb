# %%
! pip install git+https://github.com/ildoonet/pytorch-randaugment
# Out:
# ...
#   Running command git clone -q https://github.com/ildoonet/pytorch-randaugment 'C:\Users\knigh\AppData\Local\Temp\pip-req-build-bvd7rmzh'
#   Cloning https://github.com/ildoonet/pytorch-randaugment to c:\users\knigh\appdata\local\temp\pip-req-build-bvd7rmzh
# ...
#   Created wheel for RandAugment: filename=RandAugment-0.1-py3-none-any.whl size=24432 sha256=47446a1ff9b4469366163045a4f94a51df770d879a403745dcf1eb29c1ac44d7
#   Stored in directory: C:\Users\knigh\AppData\Local\Temp\pip-ephem-wheel-cache-9vuaru_2\wheels\47\22\37\4d783fdd19e380ee04188d5bb3e25213797bd61af9da870ca5
# Successfully built RandAugment
# ...
#   Attempting uninstall: RandAugment
#     Found existing installation: randaugment 1.0.2
#     Uninstalling randaugment-1.0.2:
#       Successfully uninstalled randaugment-1.0.2
# ...

# %%
from RandAugment import RandAugment
import matplotlib.pyplot as plt 
from PIL import *

# %%
composed = transforms.Compose(RandAugment(3,25)                               )

# %%
img_augment = RandAugment(3,25) #0-30
img_origal = Image.open(r'Dugong.jpg')
img_final = img_augment(img_origal)
plt.imshow(img_final)
plt.show()

# %%
img_augment = RandAugment(4,10)
img_origal = Image.open(r'Dugong.jpg')
img_final = img_augment(img_origal)
plt.imshow(img_final)
plt.show()

# %%
img_augment = RandAugment(4,15)
img_origal = Image.open(r'Dugong.jpg')
img_final = img_augment(img_origal)
plt.imshow(img_final)
plt.show()
